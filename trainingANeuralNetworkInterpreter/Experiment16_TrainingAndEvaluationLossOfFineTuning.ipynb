{'eval_loss': 0.2703184485435486, 'eval_runtime': 1488.7638, 'eval_samples_per_second': 1.014, 'eval_steps_per_second': 0.127, 'epoch': 1.85},
{'loss': 0.2667, 'learning_rate': 2.5e-05, 'epoch': 1.88},
{'eval_loss': 0.2742544710636139, 'eval_runtime': 1487.7987, 'eval_samples_per_second': 1.015, 'eval_steps_per_second': 0.127, 'epoch': 1.88},
{'loss': 0.2746, 'learning_rate': 2.5e-05, 'epoch': 1.91},
{'eval_loss': 0.26780369877815247, 'eval_runtime': 1488.021, 'eval_samples_per_second': 1.015, 'eval_steps_per_second': 0.127, 'epoch': 1.91},
{'loss': 0.276, 'learning_rate': 2.5e-05, 'epoch': 1.94},
{'eval_loss': 0.2669225335121155, 'eval_runtime': 1488.0835, 'eval_samples_per_second': 1.015, 'eval_steps_per_second': 0.127, 'epoch': 1.94},
{'loss': 0.2692, 'learning_rate': 2.5e-05, 'epoch': 1.97},
{'eval_loss': 0.2687278091907501, 'eval_runtime': 1489.4707, 'eval_samples_per_second': 1.014, 'eval_steps_per_second': 0.127, 'epoch': 1.97},
{'loss': 0.2529, 'learning_rate': 2.5e-05, 'epoch': 2.0},
{'eval_loss': 0.26455551385879517, 'eval_runtime': 1491.6052, 'eval_samples_per_second': 1.012, 'eval_steps_per_second': 0.127, 'epoch': 2.0},
{'loss': 0.2252, 'learning_rate': 2.5e-05, 'epoch': 2.03},
]

# %%
combined_data = []

for i in range(0, len(data_dict)-1, 2):
    combined = {**data_dict[i], **data_dict[i+1]}
    combined_data.append(combined)

def print_csv(data):
    print("epoch,loss,eval_loss")
    for d in data:
        print(f"{d['epoch']},{d.get('loss', '')},{d.get('eval_loss', '')}")

# Convert combined_data to DataFrame
combined_data = pd.DataFrame(combined_data, columns=['epoch', 'loss', 'eval_loss'])

combined_data[:5]
# Out:
#    epoch    loss  eval_loss
# 0   0.03  0.8996   0.683175
# 1   0.06  0.6598   0.610720
# 2   0.09  0.5827   0.566261
# 3   0.12  0.5714   0.541583
# 4   0.15  0.5494   0.521523

# %%
df = pd.read_csv('mistralLossCurve.csv')

conversion_factor = 2.4 / 4000

df['Step'] = df['Step'] * conversion_factor
df = df.rename(columns={'Step': 'epoch', 'Training Loss': 'loss', 'Validation Loss': 'eval_loss'})

# Display the adjusted DataFrame
df[:5]
# Out:
#    epoch    loss  eval_loss
# 0   0.12  0.6496   0.485940
# 1   0.24  0.4362   0.382696
# 2   0.36  0.3697   0.338850
# 3   0.48  0.3349   0.314154
# 4   0.60  0.3127   0.291455

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12, 7))

# Plot for Mistral
plt.plot(df['epoch'], df['loss'], label='Mistral7b - Training Loss', color='blue', linewidth=2, marker='o')
plt.plot(df['epoch'], df['eval_loss'], label='Mistral7b - Validation Loss', color='cyan', linewidth=2, linestyle='--', marker='x')

# Plot for Mixtral
plt.plot(combined_data['epoch'], combined_data['loss'], label='Mixtral8x7b - Training Loss', color='red', linewidth=2, marker='^')
plt.plot(combined_data['epoch'], combined_data['eval_loss'], label='Mixtral8x7b - Validation Loss', color='orange', linewidth=2, linestyle='--', marker='s')

# Adding titles, labels, and a grid
plt.title('Training and Validation Losses for Mistral7b and Mixtral8x7b', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)  # Adds a grid for easier reading

plt.savefig('loss_curve_Fine-TuningInterpreter.png')

plt.show()
